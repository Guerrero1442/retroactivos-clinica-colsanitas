# %%
import pandas as pd
from pathlib import Path

# %%
ruta_directory_zip = Path(
    r"D:\Keralty scripts\automatizaciones_python\retroactivos-clinica-colsanitas\inputs\Clinica ibague anexos 2024 y 2025.zip"
)

# %%
import zipfile

# Abrir el ZIP y leer un archivo específico
with zipfile.ZipFile(ruta_directory_zip, "r") as zip_file:
    # Ver lista de archivos dentro del ZIP
    print(zip_file.namelist())

    df_27000 = pd.read_excel(
        zip_file.open(
            "Clinica ibague anexos 2024 y 2025/27000_ANEXO_800149384_CLINICA KERALTY IBAGUE_(2024).xlsx"
        ),
        sheet_name="ANEXO",
        skiprows=17,
    )

    df_27467 = pd.read_excel(
        zip_file.open(
            "Clinica ibague anexos 2024 y 2025/27467_ANEXO_800149384_CLINICA KERALTY IBAGUE_(2024).xlsx"
        ),
        sheet_name="ANEXO",
        skiprows=17,
    )

    df_30348 = pd.read_excel(
        zip_file.open(
            "Clinica ibague anexos 2024 y 2025/30348_ANEXO_800149384_CLINICA KERALTY IBAGUE (2025).xlsx"
        ),
        sheet_name="ANEXO",
        skiprows=18,
    )
# Out:
# ['Clinica ibague anexos 2024 y 2025/27000_ANEXO_800149384_CLINICA KERALTY IBAGUE_(2024).xlsx', 'Clinica ibague anexos 2024 y 2025/27467_ANEXO_800149384_CLINICA KERALTY IBAGUE_(2024).xlsx', 'Clinica ibague anexos 2024 y 2025/30348_ANEXO_800149384_CLINICA KERALTY IBAGUE (2025).xlsx']

# %%
# eliminar columnas con Unnamed
df_27000 = df_27000.loc[:, ~df_27000.columns.str.contains("Unnamed")]

df_27000
# Out:
#      TIPO COD REPS COD\n(Res Vigente 2336 de 2023)  \
# 0      EV     1102                          890701
# 1      EV      706                          902210
# 2      EV      129                          890602
# 3      EV      706                          903895
# 4      EV      706                          903856
# ...   ...      ...                             ...
# 5417  NaN      NaN                             NaN
# 5418  NaN      NaN                             NaN
# 5419  NaN      NaN             DUVER DICSON VARGAS
# 5420  NaN      NaN     Agente Especial Interventor
# 5421  NaN      NaN                CC No.1026252683
#
#                                    COD IPS  \
# 0                                   890701
# 1                                   902210
# 2                                   890602
# 3                                   903895
# 4                                   903856
# ...                                    ...
# ...

# %%
df_27467 = df_27467.loc[:, ~df_27467.columns.str.contains("Unnamed")]

df_27467
# Out:
#                                                  TIPO  COD REPS  \
# 0                                                  EV     129.0
# 1                                                  EV     129.0
# 2                                                  PQ     215.0
# 3                                                  EV     234.0
# 4                                                  PQ     215.0
# 5                                                  EV     214.0
# 6                                                  EV     234.0
# 7                                                  EV     234.0
# 8                                                  EV     234.0
# 9                                                  PQ     215.0
# 10                                                 PQ     235.0
# 11                                                 PQ     234.0
# 12                                                NaN       NaN
# 13  1. El presente acuerdo para su formalidad debe...       NaN
# ...

# %%
df_30348 = df_30348.loc[:, ~df_30348.columns.str.contains("Unnamed")]

df_30348
# Out:
#                                                    TIPO             COD REPS  \
# 0                                                    EV                 1102
# 1                                                    EV                  706
# 2                                                    EV                  129
# 3                                                    EV                  706
# 4                                                    EV                  706
# ...                                                 ...                  ...
# 5652  Elaboró: Martha Verónica Cañas C / Coordinador...                  NaN
# 5653                                                NaN                  NaN
# 5654                                                NaN                  NaN
# 5655                                            VERSIÓN                FECHA
# 5656                                                 V1  2025-01-30 00:00:00
#
# ...

# %%
df_27000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5422 entries, 0 to 5421
# Data columns (total 21 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Unnamed: 0                                  0 non-null      float64
#  1   TIPO                                        5408 non-null   object
#  2   COD REPS                                    5404 non-null   object
#  3   COD
# (Res Vigente 2336 de 2023)              5301 non-null   object
#  4   COD IPS                                     5405 non-null   object
#  5   DESCRIPCION IPS                             5406 non-null   object
#  6   COD EPS                                     5404 non-null   object
#  7   DESCRIPCION CUPS                            5404 non-null   object
#  8   HABILITA CONCEPTOS                          5406 non-null   object
#  9   COD HOMOLOGO Manual tarifario
# ...
